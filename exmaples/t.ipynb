# %%
1
# Out:
# 1

# %%
import os


for root, dir, _ in os.walk('./example02'):
    if dir and dir[0] == '__pycache__':
        os.remove(os.path.join(root, dir[0]))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[6], line 6
#       4 for root, dir, _ in os.walk('./example02'):
#       5     if dir and dir[0] == '__pycache__':
# ----> 6         os.remove(os.path.join(root, dir[0]))
#
# PermissionError: [WinError 5] 拒绝访问。: './example02\\src\\dao\\__pycache__'
